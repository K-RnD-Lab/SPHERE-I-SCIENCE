# %% [markdown]
# # Execution Trace\n\nThis notebook is a placeholder for reproducibility notes, run logs, and manual validation snapshots for `R1a-sortsmart-ukraine`.\n\nRecommended additions after the first successful run:\n\n- environment details\n- pipeline command used\n- row counts per table\n- schema notes\n- dashboard screenshots or links\n
